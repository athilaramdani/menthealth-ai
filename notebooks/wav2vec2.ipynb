# %% [markdown]
# # Wav2Vec 2.0 Model
# This notebook contains the implementation of Wav2Vec 2.0 for mental health classification.

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2ForSequenceClassification
import torch
