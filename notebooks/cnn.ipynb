# %% [markdown]
# # CNN Model
# This notebook contains the implementation of a Convolutional Neural Network for mental health classification.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
